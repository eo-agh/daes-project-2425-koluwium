# %% [markdown]
# Mapa z punktami pomiarowymi

# %%
import sqlite3
import folium

def create_station_map(database_name: str):
    conn = sqlite3.connect(database_name)
    cursor = conn.cursor()

    cursor.execute("SELECT station_name, latitude, longitude FROM STATIONS WHERE latitude IS NOT NULL AND longitude IS NOT NULL")
    stations = cursor.fetchall()
    conn.close()

    poland_center = [52.0, 19.0]

    mapa = folium.Map(location=poland_center, zoom_start=6)

    for name, lat, lon in stations:
        folium.Marker(
            location=[lat, lon],
            popup=name,
            icon=folium.Icon(color="blue", icon="info-sign")
        ).add_to(mapa)

    return mapa

create_station_map("data.db")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_730dccf311700b200f1d632537071281 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_730dccf311700b200f1d632537071281&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_730dccf311700b200f1d632537071281 = L.map(
#                 &quot;map_730dccf311700b200f1d632537071281&quot;,
#                 {
#                     center: [52.0, 19.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c58ec0e78ea2d429a6836a73363f8acf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c58ec0e78ea2d429a6836a73363f8acf.addTo(map_730dccf311700b200f1d632537071281);
#
#
#             var marker_473794f66937bcdc0c8a6b205ee5a124 = L.marker(
#                 [53.1325, 23.1688],
#                 {
# }
#             ).addTo(map_730dccf311700b200f1d632537071281);
#
#
#             var icon_c0c0b273a4c6c8637fad50d47cff2a42 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_25d14a3fbb05168e073aa65f00c9a545 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31eeb8a43d395cc5329ef8d212ae20de = $(`&lt;div id=&quot;html_31eeb8a43d395cc5329ef8d212ae20de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Białystok&lt;/div&gt;`)[0];
#                 popup_25d14a3fbb05168e073aa65f00c9a545.setContent(html_31eeb8a43d395cc5329ef8d212ae20de);
#
#
#
#         marker_473794f66937bcdc0c8a6b205ee5a124.bindPopup(popup_25d14a3fbb05168e073aa65f00c9a545)
#         ;
#
#
#
#
#                 marker_473794f66937bcdc0c8a6b205ee5a124.setIcon(icon_c0c0b273a4c6c8637fad50d47cff2a42);
#
#
#             var marker_c037b08cc8f6466185f944eb1bc9c836 = L.marker(
#                 [49.8225, 19.0469],
#                 {
# }
#             ).addTo(map_730dccf311700b200f1d632537071281);
#
#
#             var icon_a574c86fea732f69eca1ae364fcd51a1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_74de30a4957a464a077c39f7921248ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c9f44f4f246307090e1387320e15b3e = $(`&lt;div id=&quot;html_0c9f44f4f246307090e1387320e15b3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bielsko Biała&lt;/div&gt;`)[0];
#                 popup_74de30a4957a464a077c39f7921248ce.setContent(html_0c9f44f4f246307090e1387320e15b3e);
#
#
#
#         marker_c037b08cc8f6466185f944eb1bc9c836.bindPopup(popup_74de30a4957a464a077c39f7921248ce)
#         ;
#
#
#
#
#                 marker_c037b08cc8f6466185f944eb1bc9c836.setIcon(icon_a574c86fea732f69eca1ae364fcd51a1);
#
#
#             var marker_6a4ffbdca3d6dbb49a678ee5ef752a07 = L.marker(
#                 [53.6957, 17.5566],
#                 {
# }
#             ).addTo(map_730dccf311700b200f1d632537071281);
#
#
#             var icon_2142c8c8a4554a9ebbe87752995ce43e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c6ce2721b8ba1ef2c738b7eb7b56ccaf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7c5a79dd7a08512642751ff3cd82699 = $(`&lt;div id=&quot;html_b7c5a79dd7a08512642751ff3cd82699&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chojnice&lt;/div&gt;`)[0];
#                 popup_c6ce2721b8ba1ef2c738b7eb7b56ccaf.setContent(html_b7c5a79dd7a08512642751ff3cd82699);
#
#
#
#         marker_6a4ffbdca3d6dbb49a678ee5ef752a07.bindPopup(popup_c6ce2721b8ba1ef2c738b7eb7b56ccaf)
#         ;
#
#
#
#
#                 marker_6a4ffbdca3d6dbb49a678ee5ef752a07.setIcon(icon_2142c8c8a4554a9ebbe87752995ce43e);
#
#
#             var marker_e0e8a8c844f3a821608b2b527b064210 = L.marker(
#                 [50.8118, 19.1203],
#                 {
# }
#             ).addTo(map_730dccf311700b200f1d632537071281);
#
#
#             var icon_a74bd0de837313019c52d12f68e48c0a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerCol

# %% [markdown]
# Wyświetlenie wartości temperaturowych w punktach

# %%
import sqlite3
import folium

def create_station_map(database_name: str):
    conn = sqlite3.connect(database_name)
    cursor = conn.cursor()

    # Pobranie najnowszej daty i godziny dla każdej stacji i dołączenie temperatury
    query = """
    SELECT s.station_name, s.latitude, s.longitude, m.Temperature
    FROM STATIONS s
    JOIN (
        SELECT Station_id, Temperature
        FROM METEO
        WHERE (Date, Hour) IN (
            SELECT Date, Hour
            FROM METEO
            WHERE Station_id = m.Station_id
            ORDER BY Date DESC, Hour DESC
            LIMIT 1
        )
    ) m ON s.Station_id = m.Station_id
    WHERE s.latitude IS NOT NULL AND s.longitude IS NOT NULL
    """

    # Alternatywna i bardziej przenośna wersja zapytania SQL (SQLite nie obsługuje dobrze podzapytań z aliasami w WHERE)
    query = """
    SELECT s.station_name, s.latitude, s.longitude, m.Temperature
    FROM STATIONS s
    JOIN (
        SELECT Station_id, Temperature
        FROM METEO
        WHERE (Station_id, Date, Hour) IN (
            SELECT Station_id, MAX(Date), MAX(Hour)
            FROM METEO
            GROUP BY Station_id
        )
    ) m ON s.Station_id = m.Station_id
    WHERE s.latitude IS NOT NULL AND s.longitude IS NOT NULL
    """

    cursor.execute(query)
    stations = cursor.fetchall()
    conn.close()

    poland_center = [52.0, 19.0]
    mapa = folium.Map(location=poland_center, zoom_start=6)

    for name, lat, lon, temp in stations:
        popup_text = f"{name}<br>Temperature: {temp} °C"
        folium.Marker(
            location=[lat, lon],
            popup=popup_text,
            icon=folium.Icon(color="red", icon="info-sign")
        ).add_to(mapa)

    return mapa

create_station_map("data.db")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11273963fe4a809016285d418162230a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11273963fe4a809016285d418162230a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_11273963fe4a809016285d418162230a = L.map(
#                 &quot;map_11273963fe4a809016285d418162230a&quot;,
#                 {
#                     center: [52.0, 19.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65614d4f749ed9a9a036941d21048085 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_65614d4f749ed9a9a036941d21048085.addTo(map_11273963fe4a809016285d418162230a);
#
#
#             var marker_a0f0ce97d11086a4607547a2aa62f836 = L.marker(
#                 [53.1325, 23.1688],
#                 {
# }
#             ).addTo(map_11273963fe4a809016285d418162230a);
#
#
#             var icon_f52f87e79adf06fe69a8e5323cc85758 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_890b4de3314279ecff6b93e0c4e2b7df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3cf0466e65b1dc7471cf5d1553d4d1c8 = $(`&lt;div id=&quot;html_3cf0466e65b1dc7471cf5d1553d4d1c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Białystok&lt;br&gt;Temperature: 12.8 °C&lt;/div&gt;`)[0];
#                 popup_890b4de3314279ecff6b93e0c4e2b7df.setContent(html_3cf0466e65b1dc7471cf5d1553d4d1c8);
#
#
#
#         marker_a0f0ce97d11086a4607547a2aa62f836.bindPopup(popup_890b4de3314279ecff6b93e0c4e2b7df)
#         ;
#
#
#
#
#                 marker_a0f0ce97d11086a4607547a2aa62f836.setIcon(icon_f52f87e79adf06fe69a8e5323cc85758);
#
#
#             var marker_da08f20894e48e38e7fee5a52990c10b = L.marker(
#                 [49.8225, 19.0469],
#                 {
# }
#             ).addTo(map_11273963fe4a809016285d418162230a);
#
#
#             var icon_c32553ff96b4648ad46cdbbf79d44457 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_195e3a11d60eed86445f081afc3b620d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a0a6c9170bec57af6ed1bccb529837f = $(`&lt;div id=&quot;html_3a0a6c9170bec57af6ed1bccb529837f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bielsko Biała&lt;br&gt;Temperature: 15.3 °C&lt;/div&gt;`)[0];
#                 popup_195e3a11d60eed86445f081afc3b620d.setContent(html_3a0a6c9170bec57af6ed1bccb529837f);
#
#
#
#         marker_da08f20894e48e38e7fee5a52990c10b.bindPopup(popup_195e3a11d60eed86445f081afc3b620d)
#         ;
#
#
#
#
#                 marker_da08f20894e48e38e7fee5a52990c10b.setIcon(icon_c32553ff96b4648ad46cdbbf79d44457);
#
#
#             var marker_c599780855b82623ebabec3bab9cb850 = L.marker(
#                 [53.6957, 17.5566],
#                 {
# }
#             ).addTo(map_11273963fe4a809016285d418162230a);
#
#
#             var icon_1c029587a1e46e8d8f78cb45931042f2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d720b6e0c475c1a93ed8be97ff06e071 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab28031126bb2f06bc368fd40dbee81d = $(`&lt;div id=&quot;html_ab28031126bb2f06bc368fd40dbee81d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chojnice&lt;br&gt;Temperature: 12.8 °C&lt;/div&gt;`)[0];
#                 popup_d720b6e0c475c1a93ed8be97ff06e071.setContent(html_ab28031126bb2f06bc368fd40dbee81d);
#
#
#
#         marker_c599780855b82623ebabec3bab9cb850.bindPopup(popup_d720b6e0c475c1a93ed8be97ff06e071)
#         ;
#
#
#
#
#                 marker_c599780855b82623ebabec3bab9cb850.setIcon(icon_1c029587a1e46e8d8f78cb45931042f2);
#
#
#             var marker_37507552d403242934ea3dfc6ea89db5 = L.marker(
#                 [50.8118, 19.1203],
#                 {
# }
#             ).addTo(map_11273963fe4a809016285d418162230a);
#
#
#             var icon_3fd92d

# %% [markdown]
# Pokolorowanie punktów

# %%
import sqlite3
import folium
import numpy as np

def temperature_to_color(temp, min_temp, max_temp):
    norm = (temp - min_temp) / (max_temp - min_temp) if max_temp != min_temp else 0.5
    red = int(255 * (1 - norm))
    green = int(255 * norm)
    return f'#{red:02x}{green:02x}00'

def create_station_map(database_name: str):
    conn = sqlite3.connect(database_name)
    cursor = conn.cursor()

    query = """
    SELECT s.station_name, s.latitude, s.longitude, m.Temperature
    FROM STATIONS s
    JOIN (
        SELECT Station_id, Temperature
        FROM METEO
        WHERE (Station_id, Date, Hour) IN (
            SELECT Station_id, MAX(Date), MAX(Hour)
            FROM METEO
            GROUP BY Station_id
        )
    ) m ON s.Station_id = m.Station_id
    WHERE s.latitude IS NOT NULL AND s.longitude IS NOT NULL
    """

    cursor.execute(query)
    stations = cursor.fetchall()
    conn.close()

    # Konwersja temperatur i usuwanie wartości None
    temp_data = [(name, lat, lon, float(temp)) for name, lat, lon, temp in stations if temp is not None]
    temperatures = [temp for _, _, _, temp in temp_data]

    # Obliczenie IQR i filtracja outlierów
    q1 = np.percentile(temperatures, 25)
    q3 = np.percentile(temperatures, 75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    # Filtrowanie danych bez outlierów
    filtered_data = [(name, lat, lon, temp) for name, lat, lon, temp in temp_data if lower_bound <= temp <= upper_bound]
    if not filtered_data:
        return None

    min_temp = min(temp for _, _, _, temp in filtered_data)
    max_temp = max(temp for _, _, _, temp in filtered_data)

    poland_center = [52.0, 19.0]
    mapa = folium.Map(location=poland_center, zoom_start=6)

    for name, lat, lon, temp in filtered_data:
        color = temperature_to_color(temp, min_temp, max_temp)
        popup_text = f"{name}<br>Temperature: {temp:.1f} °C"
        folium.CircleMarker(
            location=[lat, lon],
            radius=6,
            popup=popup_text,
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.9
        ).add_to(mapa)

    return mapa

create_station_map("data.db")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0fc299ef0eeea94d56ec6de1df323a30 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0fc299ef0eeea94d56ec6de1df323a30&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0fc299ef0eeea94d56ec6de1df323a30 = L.map(
#                 &quot;map_0fc299ef0eeea94d56ec6de1df323a30&quot;,
#                 {
#                     center: [52.0, 19.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1feeebcb7da469037dcba68483a072ab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1feeebcb7da469037dcba68483a072ab.addTo(map_0fc299ef0eeea94d56ec6de1df323a30);
#
#
#             var circle_marker_7508bd731724aef665b14f23d8eaa36d = L.circleMarker(
#                 [53.1325, 23.1688],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ac5200&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ac5200&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fc299ef0eeea94d56ec6de1df323a30);
#
#
#         var popup_97059518daa42afde1bb44e3708956d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_826889a075af424b2e755aa299f386fc = $(`&lt;div id=&quot;html_826889a075af424b2e755aa299f386fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Białystok&lt;br&gt;Temperature: 12.8 °C&lt;/div&gt;`)[0];
#                 popup_97059518daa42afde1bb44e3708956d7.setContent(html_826889a075af424b2e755aa299f386fc);
#
#
#
#         circle_marker_7508bd731724aef665b14f23d8eaa36d.bindPopup(popup_97059518daa42afde1bb44e3708956d7)
#         ;
#
#
#
#
#             var circle_marker_9a16f1d73edaa2a7b2ce39743a04cada = L.circleMarker(
#                 [49.8225, 19.0469],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#5f9f00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#5f9f00&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fc299ef0eeea94d56ec6de1df323a30);
#
#
#         var popup_641b485a25b336ea34f109cb2f666341 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f31275f771be782352b9baf03e9a1695 = $(`&lt;div id=&quot;html_f31275f771be782352b9baf03e9a1695&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bielsko Biała&lt;br&gt;Temperature: 15.3 °C&lt;/div&gt;`)[0];
#                 popup_641b485a25b336ea34f109cb2f666341.setContent(html_f31275f771be782352b9baf03e9a1695);
#
#
#
#         circle_marker_9a16f1d73edaa2a7b2ce39743a04cada.bindPopup(popup_641b485a25b336ea34f109cb2f666341)
#         ;
#
#
#
#
#             var circle_marker_ea8755b6815134e4dc9eb557eadc6fcf = L.circleMarker(
#                 [53.6957, 17.5566],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ac5200&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ac5200&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0fc299ef0eeea94d56ec6de1df323a30);
#
#
#         var popup_cd546c162dc4d49c350013fb17a2d983 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f6e42db11f10d67c79921bf20e9c129 = $(`&lt;div id=&quot;html_1f6e42db11f10d67c79921bf20e9c129&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chojnice&lt;br&gt;Temperature: 12.8 °C&lt;/div&gt;`)[0];
#                 popup_cd546c162dc4d49c350013fb17a2d983.setContent(html_1f6e42db11f10d67c79921bf20e9c129);
#
#
#
#         circle_marker_ea8755b6815134e4dc9eb557eadc6fcf.bindPopup(popup_cd546c162dc4d49c350013fb17a2d983)
#         ;
#
#
#
#
#             var circle_marker_3541bf721244e7b90eb758b7ac037ded = L.circleMarker(
#                 [50.8118, 19.1203],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3ac400&quot;, &quot;dashArray&quot;:

# %% [markdown]
# Przejście na siatkę gridową

# %%
import folium
import pandas as pd
import sqlite3
from matplotlib import cm, colors

conn = sqlite3.connect('data.db')

df = pd.read_sql_query("SELECT Longitude, Latitude, Temperature FROM Grid_Data", conn)

conn.close()

if df.empty:
    print("Brak danych w tabeli Grid_Data")
else:
    norm = colors.Normalize(vmin=df['Temperature'].min(), vmax=df['Temperature'].max())
    cmap = cm.get_cmap('coolwarm')

    center_lat = df['Latitude'].mean()
    center_lon = df['Longitude'].mean()

    m = folium.Map(location=[center_lat, center_lon], zoom_start=6)

    for _, row in df.iterrows():
        color = colors.rgb2hex(cmap(norm(row['Temperature'])))
        folium.CircleMarker(
            location=[row['Latitude'], row['Longitude']],
            radius=4,
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=0.7,
            popup=f"Temp: {row['Temperature']:.2f}°C"
        ).add_to(m)

m
# Out:
# C:\Users\filip\AppData\Local\Temp\ipykernel_4648\3151464068.py:16: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('coolwarm')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_625788c1a587ceaa4b48c015e6637f5c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_625788c1a587ceaa4b48c015e6637f5c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_625788c1a587ceaa4b48c015e6637f5c = L.map(
#                 &quot;map_625788c1a587ceaa4b48c015e6637f5c&quot;,
#                 {
#                     center: [52.049200000000006, 18.997000000000007],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_867b8cc8f5d73e199ef3a6e9540c2f1d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_867b8cc8f5d73e199ef3a6e9540c2f1d.addTo(map_625788c1a587ceaa4b48c015e6637f5c);
#
#
#             var circle_marker_ea3ec0462667b79d65b9ca5eebdbfb0b = L.circleMarker(
#                 [49.2992, 14.247],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f0cdbb&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f0cdbb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_625788c1a587ceaa4b48c015e6637f5c);
#
#
#         var popup_e9692636462353b069505d07daa8729d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c849099940a7eff5d830fe595cf53ac = $(`&lt;div id=&quot;html_9c849099940a7eff5d830fe595cf53ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temp: 14.21°C&lt;/div&gt;`)[0];
#                 popup_e9692636462353b069505d07daa8729d.setContent(html_9c849099940a7eff5d830fe595cf53ac);
#
#
#
#         circle_marker_ea3ec0462667b79d65b9ca5eebdbfb0b.bindPopup(popup_e9692636462353b069505d07daa8729d)
#         ;
#
#
#
#
#             var circle_marker_d374379a610f905814add73f596c911b = L.circleMarker(
#                 [49.2992, 14.747],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f0cdbb&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f0cdbb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_625788c1a587ceaa4b48c015e6637f5c);
#
#
#         var popup_d45bdb9bf4886e0ca3952bb9a740b45c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9286a2486ad41c01fdb26a70cd92500 = $(`&lt;div id=&quot;html_c9286a2486ad41c01fdb26a70cd92500&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temp: 14.21°C&lt;/div&gt;`)[0];
#                 popup_d45bdb9bf4886e0ca3952bb9a740b45c.setContent(html_c9286a2486ad41c01fdb26a70cd92500);
#
#
#
#         circle_marker_d374379a610f905814add73f596c911b.bindPopup(popup_d45bdb9bf4886e0ca3952bb9a740b45c)
#         ;
#
#
#
#
#             var circle_marker_89c57032a84ff2cb17dc872a58df834e = L.circleMarker(
#                 [49.2992, 15.247],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f0cdbb&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f0cdbb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_625788c1a587ceaa4b48c015e6637f5c);
#
#
#         var popup_f54380dcf2d7b9e762401e24ed4fbc86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a8ed55b959aca90fbcd343c921ae2fc = $(`&lt;div id=&quot;html_8a8ed55b959aca90fbcd343c921ae2fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temp: 14.20°C&lt;/div&gt;`)[0];
#                 popup_f54380dcf2d7b9e762401e24ed4fbc86.setContent(html_8a8ed55b959aca90fbcd343c921ae2fc);
#
#
#
#         circle_marker_89c57032a84ff2cb17dc872a58df834e.bindPopup(popup_f54380dcf2d7b9e762401e24ed4fbc86)
#         ;
#
#
#
#
#             var circle_marker_3221bafab3dc6cd13fb97e803d2f1c21 = L.circleMarker(
#                 [49.2992, 15.747],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#efcfbf&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: tru

# %% [markdown]
# Przycięcie do granic Polski manualnie

# %%
import folium
import pandas as pd
import sqlite3
from matplotlib import cm, colors


POLAND_BOUNDS = {
    'min_latitude': 49.0,
    'max_latitude': 55.0,
    'min_longitude': 14.0,
    'max_longitude': 24.5
}

conn = sqlite3.connect('data.db')

df = pd.read_sql_query("SELECT Longitude, Latitude, Temperature FROM Grid_Data", conn)

conn.close()

if df.empty:
    print("Brak danych w tabeli Grid_Data")
else:
    df_poland = df[
        (df['Latitude'] >= POLAND_BOUNDS['min_latitude']) &
        (df['Latitude'] <= POLAND_BOUNDS['max_latitude']) &
        (df['Longitude'] >= POLAND_BOUNDS['min_longitude']) &
        (df['Longitude'] <= POLAND_BOUNDS['max_longitude'])
    ]

    if df_poland.empty:
        print("Brak danych w tabeli Grid_Data w granicach Polski.")
    else:
        norm = colors.Normalize(vmin=df_poland['Temperature'].min(), vmax=df_poland['Temperature'].max())
        cmap = cm.get_cmap('coolwarm')

        center_lat = 52.0 
        center_lon = 19.0 

        m = folium.Map(location=[center_lat, center_lon], zoom_start=6)

        for _, row in df_poland.iterrows():
            color = colors.rgb2hex(cmap(norm(row['Temperature'])))
            folium.CircleMarker(
                location=[row['Latitude'], row['Longitude']],
                radius=4,
                color=color,
                fill=True,
                fill_color=color,
                fill_opacity=0.7,
                popup=f"Temp: {row['Temperature']:.2f}°C"
            ).add_to(m)

        display(m)
# Out:
# C:\Users\filip\AppData\Local\Temp\ipykernel_4648\4174373671.py:37: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('coolwarm')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0dae19578b0dc06cda88f6035115907 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0dae19578b0dc06cda88f6035115907&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c0dae19578b0dc06cda88f6035115907 = L.map(
#                 &quot;map_c0dae19578b0dc06cda88f6035115907&quot;,
#                 {
#                     center: [52.0, 19.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46b570bdd725af058f27544e1beb606f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_46b570bdd725af058f27544e1beb606f.addTo(map_c0dae19578b0dc06cda88f6035115907);
#
#
#             var circle_marker_a6840617ee281ff2dec63bd8f7c1af2f = L.circleMarker(
#                 [49.2992, 14.247],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f0cdbb&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f0cdbb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c0dae19578b0dc06cda88f6035115907);
#
#
#         var popup_4b9cadc89da2e8ea295fd1e05e89fb36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d03aa0b824e435dbb153dc4bf862bb6a = $(`&lt;div id=&quot;html_d03aa0b824e435dbb153dc4bf862bb6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temp: 14.21°C&lt;/div&gt;`)[0];
#                 popup_4b9cadc89da2e8ea295fd1e05e89fb36.setContent(html_d03aa0b824e435dbb153dc4bf862bb6a);
#
#
#
#         circle_marker_a6840617ee281ff2dec63bd8f7c1af2f.bindPopup(popup_4b9cadc89da2e8ea295fd1e05e89fb36)
#         ;
#
#
#
#
#             var circle_marker_52aa1ca313311b4899a6c38eb516c0a9 = L.circleMarker(
#                 [49.2992, 14.747],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f0cdbb&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f0cdbb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c0dae19578b0dc06cda88f6035115907);
#
#
#         var popup_8a956abafb35e7bf78f2c2594c48d393 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae84987cdbc38ce2f057b7442ea4a1a2 = $(`&lt;div id=&quot;html_ae84987cdbc38ce2f057b7442ea4a1a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temp: 14.21°C&lt;/div&gt;`)[0];
#                 popup_8a956abafb35e7bf78f2c2594c48d393.setContent(html_ae84987cdbc38ce2f057b7442ea4a1a2);
#
#
#
#         circle_marker_52aa1ca313311b4899a6c38eb516c0a9.bindPopup(popup_8a956abafb35e7bf78f2c2594c48d393)
#         ;
#
#
#
#
#             var circle_marker_6c4a7655d4d5e2ea20826eb67f454840 = L.circleMarker(
#                 [49.2992, 15.247],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f0cdbb&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f0cdbb&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c0dae19578b0dc06cda88f6035115907);
#
#
#         var popup_f8ed8ee955461305e13e2e86fcfd0f11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52415f27787b790282881d10920c2c36 = $(`&lt;div id=&quot;html_52415f27787b790282881d10920c2c36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temp: 14.20°C&lt;/div&gt;`)[0];
#                 popup_f8ed8ee955461305e13e2e86fcfd0f11.setContent(html_52415f27787b790282881d10920c2c36);
#
#
#
#         circle_marker_6c4a7655d4d5e2ea20826eb67f454840.bindPopup(popup_f8ed8ee955461305e13e2e86fcfd0f11)
#         ;
#
#
#
#
#             var circle_marker_ba0e7e28cd05e79a981b6d8358f9bcc9 = L.circleMarker(
#                 [49.2992, 15.747],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#efcfbf&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &q

# %% [markdown]
# Przycięcie do granic polski używając plik JSON

# %%
import folium
import pandas as pd
import sqlite3
from matplotlib import cm, colors
import json
from shapely.geometry import Point, shape 


conn = sqlite3.connect('data.db')

df = pd.read_sql_query("SELECT Longitude, Latitude, Temperature FROM Grid_Data", conn)

conn.close()

if df.empty:
    print("Brak danych w tabeli Grid_Data")
else:
    try:
        with open('poland.country.json', 'r', encoding='utf-8') as f:
            poland_geojson = json.load(f)

        if poland_geojson['type'] == 'FeatureCollection':
            poland_geometry = poland_geojson['features'][0]['geometry']
        elif poland_geojson['type'] == 'Feature':
            poland_geometry = poland_geojson['geometry']
        else: 
            poland_geometry = poland_geojson

        poland_polygon = shape(poland_geometry)
        print("Pomyślnie wczytano plik poland.json i utworzono obiekt Polygon.")

    except FileNotFoundError:
        print("Błąd: Plik 'poland.json' nie został znaleziony. Upewnij się, że znajduje się w tym samym katalogu.")
        exit() 
    except json.JSONDecodeError:
        print("Błąd: Nie można odczytać pliku 'poland.json'. Sprawdź, czy jest to poprawny plik JSON.")
        exit()
    except KeyError as e:
        print(f"Błąd w strukturze pliku poland.json: Brak klucza {e}. Sprawdź, czy plik zawiera poprawną geometrię.")
        exit()
    except Exception as e:
        print(f"Wystąpił nieoczekiwany błąd podczas ładowania pliku poland.json: {e}")
        exit()


    df_poland_list = []
    for index, row in df.iterrows():
        point = Point(row['Longitude'], row['Latitude'])
        if poland_polygon.contains(point):
            df_poland_list.append(row)
    
    df_poland = pd.DataFrame(df_poland_list)

    if df_poland.empty:
        print("Brak danych w tabeli Grid_Data w granicach Polski (zgodnie z poland.json).")
    else:
        norm = colors.Normalize(vmin=df_poland['Temperature'].min(), vmax=df_poland['Temperature'].max())
        cmap = cm.get_cmap('coolwarm')

        center_lat = 52.0 
        center_lon = 19.0 

        m = folium.Map(location=[center_lat, center_lon], zoom_start=6)

        for _, row in df_poland.iterrows():
            color = colors.rgb2hex(cmap(norm(row['Temperature'])))
            folium.CircleMarker(
                location=[row['Latitude'], row['Longitude']],
                radius=4,
                color=color,
                fill=True,
                fill_color=color,
                fill_opacity=0.7,
                popup=f"Temp: {row['Temperature']:.2f}°C"
            ).add_to(m)

        folium.GeoJson(poland_geojson, name='Poland Borders').add_to(m)
        print("Granice Polski dodano do mapy.")

m
# Out:
# Pomyślnie wczytano plik poland.json i utworzono obiekt Polygon.
# Granice Polski dodano do mapy.
# C:\Users\filip\AppData\Local\Temp\ipykernel_11276\1755492300.py:58: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('coolwarm')
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59a5c40e6de2af369ec4dbb0b8834814 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59a5c40e6de2af369ec4dbb0b8834814&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59a5c40e6de2af369ec4dbb0b8834814 = L.map(
#                 &quot;map_59a5c40e6de2af369ec4dbb0b8834814&quot;,
#                 {
#                     center: [52.0, 19.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70506e7367eccd4ef0a4a1811ef6a1b7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_70506e7367eccd4ef0a4a1811ef6a1b7.addTo(map_59a5c40e6de2af369ec4dbb0b8834814);
#
#
#             var circle_marker_23cc9338c202960e557a1fe4cd6bb5f4 = L.circleMarker(
#                 [49.2992, 22.247],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#adc9fd&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#adc9fd&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_59a5c40e6de2af369ec4dbb0b8834814);
#
#
#         var popup_73997baddd05d6fd3d70dcf18d9179b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fe7e321f32d6ba317523ff30d485d74 = $(`&lt;div id=&quot;html_6fe7e321f32d6ba317523ff30d485d74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temp: 12.92°C&lt;/div&gt;`)[0];
#                 popup_73997baddd05d6fd3d70dcf18d9179b0.setContent(html_6fe7e321f32d6ba317523ff30d485d74);
#
#
#
#         circle_marker_23cc9338c202960e557a1fe4cd6bb5f4.bindPopup(popup_73997baddd05d6fd3d70dcf18d9179b0)
#         ;
#
#
#
#
#             var circle_marker_a6c6bd46a4f7b669e80c16e090e056f7 = L.circleMarker(
#                 [49.7992, 18.747],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#e16751&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e16751&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_59a5c40e6de2af369ec4dbb0b8834814);
#
#
#         var popup_bfb4d44102130c3980182f0c6dab561f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0817517150670c667c72da11d3598195 = $(`&lt;div id=&quot;html_0817517150670c667c72da11d3598195&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temp: 15.66°C&lt;/div&gt;`)[0];
#                 popup_bfb4d44102130c3980182f0c6dab561f.setContent(html_0817517150670c667c72da11d3598195);
#
#
#
#         circle_marker_a6c6bd46a4f7b669e80c16e090e056f7.bindPopup(popup_bfb4d44102130c3980182f0c6dab561f)
#         ;
#
#
#
#
#             var circle_marker_b184b335922e8656cd9217bcc7d42c04 = L.circleMarker(
#                 [49.7992, 19.247],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d85646&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d85646&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_59a5c40e6de2af369ec4dbb0b8834814);
#
#
#         var popup_6271632f02c49e50ed95156827652704 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f66e0f090d98eeb0aea5ddd865fd2c42 = $(`&lt;div id=&quot;html_f66e0f090d98eeb0aea5ddd865fd2c42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Temp: 15.82°C&lt;/div&gt;`)[0];
#                 popup_6271632f02c49e50ed95156827652704.setContent(html_f66e0f090d98eeb0aea5ddd865fd2c42);
#
#
#
#         circle_marker_b184b335922e8656cd9217bcc7d42c04.bindPopup(popup_6271632f02c49e50ed95156827652704)
#         ;
#
#
#
#
#             var circle_marker_46a1261bb620781b4c61e724fcbcac55 = L.circleMarker(
#                 [49.7992, 19.747],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d95847&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &q
